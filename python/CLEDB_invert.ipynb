# %%
# Needed libraries
#
import numpy as np
from numba import jit, njit, prange

#numba.config.DEBUG_ARRAY_OPT=1
#numba.config.NUMBA_PARALLEL_DIAGNOSTICS=1
#from scipy.io import FortranFile
#from scipy import stats

import time
#import sys
import importlib
import pickle

import cledb_utils_par as cle202_utils   # Utilities to help the inversion

# %% [markdown]
# ## 3 types of simulated/faked observations

# %%
## use fake_obs to just generate a random map.
# FE XIII 1074+1079
## This has the benefit of also testing the uncertainty implementation
## THIS IS VERY HACKISH!

# with open('obsstokes_dbfake.pkl','rb') as f:
#     sobs_a,yobs_a,rms,xxl,yyl = pickle.load(f)

# %%
## load the CLE 3dipole fake observation data
## FE XIII 1074+1079
## sobs_a is normalized to first column (stokes I 1074)
## RMS is 1 in this example; observation can be convoluted with noise if needed and re-normalized again

with open('obsstokes_3dipole_hires.pkl','rb') as f:
    sobs_a,yobs_a,rms,xxl,yyl = pickle.load(f)

# %%
## load the fake observation muram data.
## FE XIII 1074+1079
## sobs_a is normalized to first column (stokes I 1074)
## RMS is 1 in this example; observation can be convoluted with noise if needed and re-normalized again

# with open('obsstokes_avg_muram.pkl','rb') as f:
#     f1aa,f2aa,sobs_a,yobs_a,rms,wvl,xxl,yyl = pickle.load(f)    

# with open('obsstokes_avg_muram2.pkl','rb') as f:
#     sobs_a,yobs_a,rms,xxl,yyl = pickle.load(f)

# %% [markdown]
# # DBINVERT MAIN!

# %%
################This is the DBINVERT script#################### 
importlib.reload(cle202_utils)

##Global constants & main controling parameters:

reduce = np.int_(1)  ## Uses native simmetries to reduce the database search; really fast only if enabled.
chi2   = np.int_(50) ## the maximum chi^2 to return; ideally a normalized and reduced chi^2 should be <1
ns     = np.int_(12)  ##maximum number of solutions to return

## Twoline databases are implemented; individual ion databases are partially implemented (a switcher to select what combination is requested is missing).
#dbdir1  = '/home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_deg_150_fe13/' ## main directory containing the two line Fe XIII DB entries; 
dbdir  = '/home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/' ## main directory containing the individual ion DB entries; 

verbose= np.int_(3)  ## incremental verbosity of inversion operations
##not fully implememted
#verbose=1 gives prints for current operation being done
#verbose=2 implements warnings for common caveats.
#Verbose=3 will enable execution timing for sections that are not numba non-python enabled.

out=np.zeros((xxl,yyl,ns,11),dtype=np.float64)     
iquv_match=np.empty((xxl,yyl,ns,8),dtype=np.float64)
#Arrays to store the DBINVERT solutions. Provisioned to store the maximum amount of solutions retrievable(ns). 
#The inversion can produce less than ns solution due to the chi2 condition.
##out[0],[1] are the DB index and chi2 fit values respectively.
##out[2],[3],[4] are the plasma density, radial height position (y), and los position (x)
##out[5],[6],[7] are the LVS field B (scaled using the V_obs/V_db ratio) with phi and theta angles
##out[8],[9],[10] are bx by bz scaled using the V_obs/V_db ratio

if verbose >=1:
    print('####################################\n##########DBINVERT STARTED##########\n####################################')
    if verbose >=3: start=time.time()

# fenc,db1,hdrparams=cle202_utils.db_find(yobs_a,
#                                              dbdir1,
#                                              xxl,
#                                              yyl,
#                                              verbose)  
fenc,db,hdrparams=cle202_utils.db_find(yobs_a,
                                             dbdir,
                                             xxl,
                                             yyl,
                                             verbose)
# Out:
# ####################################
# ##########DBINVERT STARTED##########
# ####################################
# ------------DB READ START-----------
# DB covers a span of  14  heights between 1.001 - 1.47 Solar radius
# Load  14  DB heights in memory
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0450.DAT
# 77  MB in DB file
# 0.280935  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0450.DAT
# 77  MB in DB file
# 0.396771  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0220.DAT
# 77  MB in DB file
# 0.427613  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0220.DAT
# 77  MB in DB file
# 0.327449  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0301.DAT
# 77  MB in DB file
# 0.292332  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0301.DAT
# 77  MB in DB file
# 0.301411  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0001.DAT
# 77  MB in DB file
# 0.403595  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0001.DAT
# 77  MB in DB file
# 0.318311  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0370.DAT
# 77  MB in DB file
# 0.322868  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0370.DAT
# 77  MB in DB file
# 0.796716  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0100.DAT
# 77  MB in DB file
# 0.358648  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0100.DAT
# 77  MB in DB file
# 0.436688  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0401.DAT
# 77  MB in DB file
# 0.647475  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0401.DAT
# 77  MB in DB file
# 0.487586  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0151.DAT
# 77  MB in DB file
# 0.572652  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0151.DAT
# 77  MB in DB file
# 0.650898  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0251.DAT
# 77  MB in DB file
# 0.625248  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0251.DAT
# 77  MB in DB file
# 0.601934  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0470.DAT
# 77  MB in DB file
# 0.621408  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0470.DAT
# 77  MB in DB file
# 0.602702  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0070.DAT
# 77  MB in DB file
# 0.642324  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0070.DAT
# 77  MB in DB file
# 0.516480  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0170.DAT
# 77  MB in DB file
# 0.725180  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0170.DAT
# 77  MB in DB file
# 0.605335  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0320.DAT
# 77  MB in DB file
# 0.614429  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0320.DAT
# 77  MB in DB file
# 0.519275  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0020.DAT
# 77  MB in DB file
# 0.668856  SECONDS FOR INDIVIDUAL DB READ
# ----------
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0020.DAT
# 77  MB in DB file
# 0.583914  SECONDS FOR INDIVIDUAL DB READ
# ----------
# 31.123391  SECONDS FOR TOTAL DB SEARCH AND FIND
# --------------DB READ FINALIZED----------------

# %%
importlib.reload(cle202_utils)

if verbose >=1: print('------------TWO LINE INVERSION START-----------')
@njit(parallel=True)
def dbinvert_twoline_par(sobs,database,fe,yobs,dbdir,rms,hdrparams,xxl,yyl,nsearch,reduced,verbose):
    
    ##Output variables
    outparams=np.zeros((xxl,yyl,nsearch,11),dtype=np.float64)     
    smatch  =np.zeros((xxl,yyl,nsearch,8),dtype=np.float64)  
    
    ## Number of degrees of freedom >4; we require a two line full IQUV observation.
    ## assume the last dimension of sobs is the number of observables; 2 lines=8
    ## Database needs to match the observation
    if sobs.shape[-1] != 8 or database[0].shape[-1] != 8: 
        print('clematch: Must have a two line observation and/or a corresponding two line database; Aborting!')
        if verbose >=1: print("Shapes are: ", sobs.shape," and ",database[0].shape)
        outparams[:,:,:,0]=np.full((xxl,yyl,nsearch),-1) ### index is -1 for failed runs!
        return outparams,smatch
    
    
#     index   = np.empty((xxl,yyl,nsearch),dtype=np.int_)
#     chisq   = np.empty((xxl,yyl,nsearch),dtype=np.float64)
#     physics = np.empty((xxl,yyl,nsearch,9),dtype=np.float64)

    if verbose >= 1:      
        for xx in range(xxl):
            print("Executing ext. loop:",xx," of ",xxl," (",yyl," calculations / loop)")
            for yy in prange(yyl):
#                 index[xx,yy,:],smatch[xx,yy,:,:],chisq[xx,yy,:],physics[xx,yy,:,:]=cle202_utils.clematch_par(sobs[xx,yy,:],
#                                                                                                              yobs[xx,yy],
#                                                                                                              database[fe[xx,yy]],
#                                                                                                              hdrparams,
#                                                                                                              rms,
#                                                                                                              '',
#                                                                                                              chi2,
#                                                                                                              nsearch,
#                                                                                                              reduced,
#                                                                                                              0)

                outparams[xx,yy,:,:],smatch[xx,yy,:,:]=cle202_utils.clematch_par(sobs[xx,yy,:],yobs[xx,yy],database[fe[xx,yy]],hdrparams, rms, '', chi2,nsearch, reduced, 0)
          
            
            #outparams[xx,yy,:,0]=index[xx,yy,:]
            #outparams[xx,yy,:,1]=chisq[xx,yy,:]
            #outparams[xx,yy,:,2:11]=physics[xx,yy,:,:]
#     else:
#         for xx in range(xxl):
#             for yy in prange(yyl):

#                 index[xx,yy,:],smatch[xx,yy,:,:],chisq[xx,yy,:],physics[xx,yy,:,:]=cle202_utils.clematch_par(sobs[xx,yy,:],
#                                                                                                              yobs[xx,yy],
#                                                                                                              database[fe[xx,yy]],
#                                                                                                              hdrparams,
#                                                                                                              rms,                                         '',
#                                                                                                              chi2,
#                                                                                                              nsearch,
#                                                                                                              reduced,
#                                                                                                              verbose)        
               
#     outparams[:,:,:,0]=index
#     outparams[:,:,:,1]=chisq
#     outparams[:,:,:,2:11]=physics

    return outparams,smatch

out,iquv_match=dbinvert_twoline_par(sobs_a,db,fenc,yobs_a,dbdir,rms,hdrparams,xxl,yyl,ns,reduce,verbose)


if verbose >=1:
    print('####################################\n##########DBINVERT FINALIZED##########\n####################################')
    if verbose >=3: print("{:4.6f}".format(time.time()-start),' TOTAL SECONDS FOR DBINVERT ')
# Out:
# ------------TWO LINE INVERSION START-----------
# Executing ext. loop: 0  of  280  ( 600  calculations / loop)
# Executing ext. loop: 1  of  280  ( 600  calculations / loop)
# Executing ext. loop: 2  of  280  ( 600  calculations / loop)
# Executing ext. loop: 3  of  280  ( 600  calculations / loop)
# Executing ext. loop: 4  of  280  ( 600  calculations / loop)
# Executing ext. loop: 5  of  280  ( 600  calculations / loop)
# Executing ext. loop: 6  of  280  ( 600  calculations / loop)
# Executing ext. loop: 7  of  280  ( 600  calculations / loop)
# Executing ext. loop: 8  of  280  ( 600  calculations / loop)
# Executing ext. loop: 9  of  280  ( 600  calculations / loop)
# Executing ext. loop: 10  of  280  ( 600  calculations / loop)
# Executing ext. loop: 11  of  280  ( 600  calculations / loop)
# Executing ext. loop: 12  of  280  ( 600  calculations / loop)
# Executing ext. loop: 13  of  280  ( 600  calculations / loop)
# Executing ext. loop: 14  of  280  ( 600  calculations / loop)
# Executing ext. loop: 15  of  280  ( 600  calculations / loop)
# Executing ext. loop: 16  of  280  ( 600  calculations / loop)
# Executing ext. loop: 17  of  280  ( 600  calculations / loop)
# Executing ext. loop: 18  of  280  ( 600  calculations / loop)
# Executing ext. loop: 19  of  280  ( 600  calculations / loop)
# Executing ext. loop: 20  of  280  ( 600  calculations / loop)
# Executing ext. loop: 21  of  280  ( 600  calculations / loop)
# Executing ext. loop: 22  of  280  ( 600  calculations / loop)
# Executing ext. loop: 23  of  280  ( 600  calculations / loop)
# Executing ext. loop: 24  of  280  ( 600  calculations / loop)
# Executing ext. loop: 25  of  280  ( 600  calculations / loop)
# Executing ext. loop: 26  of  280  ( 600  calculations / loop)
# Executing ext. loop: 27  of  280  ( 600  calculations / loop)
# Executing ext. loop: 28  of  280  ( 600  calculations / loop)
# Executing ext. loop: 29  of  280  ( 600  calculations / loop)
# Executing ext. loop: 30  of  280  ( 600  calculations / loop)
# Executing ext. loop: 31  of  280  ( 600  calculations / loop)
# Executing ext. loop: 32  of  280  ( 600  calculations / loop)
# Executing ext. loop: 33  of  280  ( 600  calculations / loop)
# Executing ext. loop: 34  of  280  ( 600  calculations / loop)
# Executing ext. loop: 35  of  280  ( 600  calculations / loop)
# Executing ext. loop: 36  of  280  ( 600  calculations / loop)
# Executing ext. loop: 37  of  280  ( 600  calculations / loop)
# Executing ext. loop: 38  of  280  ( 600  calculations / loop)
# Executing ext. loop: 39  of  280  ( 600  calculations / loop)
# Executing ext. loop: 40  of  280  ( 600  calculations / loop)
# Executing ext. loop: 41  of  280  ( 600  calculations / loop)
# Executing ext. loop: 42  of  280  ( 600  calculations / loop)
# Executing ext. loop: 43  of  280  ( 600  calculations / loop)
# Executing ext. loop: 44  of  280  ( 600  calculations / loop)
# Executing ext. loop: 45  of  280  ( 600  calculations / loop)
# Executing ext. loop: 46  of  280  ( 600  calculations / loop)
# Executing ext. loop: 47  of  280  ( 600  calculations / loop)
# Executing ext. loop: 48  of  280  ( 600  calculations / loop)
# Executing ext. loop: 49  of  280  ( 600  calculations / loop)
# Executing ext. loop: 50  of  280  ( 600  calculations / loop)
# Executing ext. loop: 51  of  280  ( 600  calculations / loop)
# Executing ext. loop: 52  of  280  ( 600  calculations / loop)
# Executing ext. loop: 53  of  280  ( 600  calculations / loop)
# Executing ext. loop: 54  of  280  ( 600  calculations / loop)
# Executing ext. loop: 55  of  280  ( 600  calculations / loop)
# Executing ext. loop: 56  of  280  ( 600  calculations / loop)
# Executing ext. loop: 57  of  280  ( 600  calculations / loop)
# Executing ext. loop: 58  of  280  ( 600  calculations / loop)
# Executing ext. loop: 59  of  280  ( 600  calculations / loop)
# Executing ext. loop: 60  of  280  ( 600  calculations / loop)
# Executing ext. loop: 61  of  280  ( 600  calculations / loop)
# Executing ext. loop: 62  of  280  ( 600  calculations / loop)
# Executing ext. loop: 63  of  280  ( 600  calculations / loop)
# Executing ext. loop: 64  of  280  ( 600  calculations / loop)
# Executing ext. loop: 65  of  280  ( 600  calculations / loop)
# Executing ext. loop: 66  of  280  ( 600  calculations / loop)
# Executing ext. loop: 67  of  280  ( 600  calculations / loop)
# Executing ext. loop: 68  of  280  ( 600  calculations / loop)
# Executing ext. loop: 69  of  280  ( 600  calculations / loop)
# Executing ext. loop: 70  of  280  ( 600  calculations / loop)
# Executing ext. loop: 71  of  280  ( 600  calculations / loop)
# Executing ext. loop: 72  of  280  ( 600  calculations / loop)
# Executing ext. loop: 73  of  280  ( 600  calculations / loop)
# Executing ext. loop: 74  of  280  ( 600  calculations / loop)
# Executing ext. loop: 75  of  280  ( 600  calculations / loop)
# Executing ext. loop: 76  of  280  ( 600  calculations / loop)
# Executing ext. loop: 77  of  280  ( 600  calculations / loop)
# Executing ext. loop: 78  of  280  ( 600  calculations / loop)
# Executing ext. loop: 79  of  280  ( 600  calculations / loop)
# Executing ext. loop: 80  of  280  ( 600  calculations / loop)
# Executing ext. loop: 81  of  280  ( 600  calculations / loop)
# Executing ext. loop: 82  of  280  ( 600  calculations / loop)
# Executing ext. loop: 83  of  280  ( 600  calculations / loop)
# Executing ext. loop: 84  of  280  ( 600  calculations / loop)
# Executing ext. loop: 85  of  280  ( 600  calculations / loop)
# Executing ext. loop: 86  of  280  ( 600  calculations / loop)
# Executing ext. loop: 87  of  280  ( 600  calculations / loop)
# Executing ext. loop: 88  of  280  ( 600  calculations / loop)
# Executing ext. loop: 89  of  280  ( 600  calculations / loop)
# Executing ext. loop: 90  of  280  ( 600  calculations / loop)
# Executing ext. loop: 91  of  280  ( 600  calculations / loop)
# Executing ext. loop: 92  of  280  ( 600  calculations / loop)
# Executing ext. loop: 93  of  280  ( 600  calculations / loop)
# Executing ext. loop: 94  of  280  ( 600  calculations / loop)
# Executing ext. loop: 95  of  280  ( 600  calculations / loop)
# Executing ext. loop: 96  of  280  ( 600  calculations / loop)
# Executing ext. loop: 97  of  280  ( 600  calculations / loop)
# Executing ext. loop: 98  of  280  ( 600  calculations / loop)
# Executing ext. loop: 99  of  280  ( 600  calculations / loop)
# Executing ext. loop: 100  of  280  ( 600  calculations / loop)
# Executing ext. loop: 101  of  280  ( 600  calculations / loop)
# Executing ext. loop: 102  of  280  ( 600  calculations / loop)
# Executing ext. loop: 103  of  280  ( 600  calculations / loop)
# Executing ext. loop: 104  of  280  ( 600  calculations / loop)
# Executing ext. loop: 105  of  280  ( 600  calculations / loop)
# Executing ext. loop: 106  of  280  ( 600  calculations / loop)
# Executing ext. loop: 107  of  280  ( 600  calculations / loop)
# Executing ext. loop: 108  of  280  ( 600  calculations / loop)
# Executing ext. loop: 109  of  280  ( 600  calculations / loop)
# Executing ext. loop: 110  of  280  ( 600  calculations / loop)
# Executing ext. loop: 111  of  280  ( 600  calculations / loop)
# Executing ext. loop: 112  of  280  ( 600  calculations / loop)
# Executing ext. loop: 113  of  280  ( 600  calculations / loop)
# Executing ext. loop: 114  of  280  ( 600  calculations / loop)
# Executing ext. loop: 115  of  280  ( 600  calculations / loop)
# Executing ext. loop: 116  of  280  ( 600  calculations / loop)
# Executing ext. loop: 117  of  280  ( 600  calculations / loop)
# Executing ext. loop: 118  of  280  ( 600  calculations / loop)
# Executing ext. loop: 119  of  280  ( 600  calculations / loop)
# Executing ext. loop: 120  of  280  ( 600  calculations / loop)
# Executing ext. loop: 121  of  280  ( 600  calculations / loop)
# Executing ext. loop: 122  of  280  ( 600  calculations / loop)
# Executing ext. loop: 123  of  280  ( 600  calculations / loop)
# Executing ext. loop: 124  of  280  ( 600  calculations / loop)
# Executing ext. loop: 125  of  280  ( 600  calculations / loop)
# Executing ext. loop: 126  of  280  ( 600  calculations / loop)
# Executing ext. loop: 127  of  280  ( 600  calculations / loop)
# Executing ext. loop: 128  of  280  ( 600  calculations / loop)
# Executing ext. loop: 129  of  280  ( 600  calculations / loop)
# Executing ext. loop: 130  of  280  ( 600  calculations / loop)
# Executing ext. loop: 131  of  280  ( 600  calculations / loop)
# Executing ext. loop: 132  of  280  ( 600  calculations / loop)
# Executing ext. loop: 133  of  280  ( 600  calculations / loop)
# Executing ext. loop: 134  of  280  ( 600  calculations / loop)
# Executing ext. loop: 135  of  280  ( 600  calculations / loop)
# Executing ext. loop: 136  of  280  ( 600  calculations / loop)
# Executing ext. loop: 137  of  280  ( 600  calculations / loop)
# Executing ext. loop: 138  of  280  ( 600  calculations / loop)
# Executing ext. loop: 139  of  280  ( 600  calculations / loop)
# Executing ext. loop: 140  of  280  ( 600  calculations / loop)
# Executing ext. loop: 141  of  280  ( 600  calculations / loop)
# Executing ext. loop: 142  of  280  ( 600  calculations / loop)
# Executing ext. loop: 143  of  280  ( 600  calculations / loop)
# Executing ext. loop: 144  of  280  ( 600  calculations / loop)
# Executing ext. loop: 145  of  280  ( 600  calculations / loop)
# Executing ext. loop: 146  of  280  ( 600  calculations / loop)
# Executing ext. loop: 147  of  280  ( 600  calculations / loop)
# Executing ext. loop: 148  of  280  ( 600  calculations / loop)
# Executing ext. loop: 149  of  280  ( 600  calculations / loop)
# Executing ext. loop: 150  of  280  ( 600  calculations / loop)
# Executing ext. loop: 151  of  280  ( 600  calculations / loop)
# Executing ext. loop: 152  of  280  ( 600  calculations / loop)
# Executing ext. loop: 153  of  280  ( 600  calculations / loop)
# Executing ext. loop: 154  of  280  ( 600  calculations / loop)
# Executing ext. loop: 155  of  280  ( 600  calculations / loop)
# Executing ext. loop: 156  of  280  ( 600  calculations / loop)
# Executing ext. loop: 157  of  280  ( 600  calculations / loop)
# Executing ext. loop: 158  of  280  ( 600  calculations / loop)
# Executing ext. loop: 159  of  280  ( 600  calculations / loop)
# Executing ext. loop: 160  of  280  ( 600  calculations / loop)
# Executing ext. loop: 161  of  280  ( 600  calculations / loop)
# Executing ext. loop: 162  of  280  ( 600  calculations / loop)
# Executing ext. loop: 163  of  280  ( 600  calculations / loop)
# Executing ext. loop: 164  of  280  ( 600  calculations / loop)
# Executing ext. loop: 165  of  280  ( 600  calculations / loop)
# Executing ext. loop: 166  of  280  ( 600  calculations / loop)
# Executing ext. loop: 167  of  280  ( 600  calculations / loop)
# Executing ext. loop: 168  of  280  ( 600  calculations / loop)
# Executing ext. loop: 169  of  280  ( 600  calculations / loop)
# Executing ext. loop: 170  of  280  ( 600  calculations / loop)
# Executing ext. loop: 171  of  280  ( 600  calculations / loop)
# Executing ext. loop: 172  of  280  ( 600  calculations / loop)
# Executing ext. loop: 173  of  280  ( 600  calculations / loop)
# Executing ext. loop: 174  of  280  ( 600  calculations / loop)
# Executing ext. loop: 175  of  280  ( 600  calculations / loop)
# Executing ext. loop: 176  of  280  ( 600  calculations / loop)
# Executing ext. loop: 177  of  280  ( 600  calculations / loop)
# Executing ext. loop: 178  of  280  ( 600  calculations / loop)
# Executing ext. loop: 179  of  280  ( 600  calculations / loop)
# Executing ext. loop: 180  of  280  ( 600  calculations / loop)
# Executing ext. loop: 181  of  280  ( 600  calculations / loop)
# Executing ext. loop: 182  of  280  ( 600  calculations / loop)
# Executing ext. loop: 183  of  280  ( 600  calculations / loop)
# Executing ext. loop: 184  of  280  ( 600  calculations / loop)
# Executing ext. loop: 185  of  280  ( 600  calculations / loop)
# Executing ext. loop: 186  of  280  ( 600  calculations / loop)
# Executing ext. loop: 187  of  280  ( 600  calculations / loop)
# Executing ext. loop: 188  of  280  ( 600  calculations / loop)
# Executing ext. loop: 189  of  280  ( 600  calculations / loop)
# Executing ext. loop: 190  of  280  ( 600  calculations / loop)
# Executing ext. loop: 191  of  280  ( 600  calculations / loop)
# Executing ext. loop: 192  of  280  ( 600  calculations / loop)
# Executing ext. loop: 193  of  280  ( 600  calculations / loop)
# Executing ext. loop: 194  of  280  ( 600  calculations / loop)
# Executing ext. loop: 195  of  280  ( 600  calculations / loop)
# Executing ext. loop: 196  of  280  ( 600  calculations / loop)
# Executing ext. loop: 197  of  280  ( 600  calculations / loop)
# Executing ext. loop: 198  of  280  ( 600  calculations / loop)
# Executing ext. loop: 199  of  280  ( 600  calculations / loop)
# Executing ext. loop: 200  of  280  ( 600  calculations / loop)
# Executing ext. loop: 201  of  280  ( 600  calculations / loop)
# Executing ext. loop: 202  of  280  ( 600  calculations / loop)
# Executing ext. loop: 203  of  280  ( 600  calculations / loop)
# Executing ext. loop: 204  of  280  ( 600  calculations / loop)
# Executing ext. loop: 205  of  280  ( 600  calculations / loop)
# Executing ext. loop: 206  of  280  ( 600  calculations / loop)
# Executing ext. loop: 207  of  280  ( 600  calculations / loop)
# Executing ext. loop: 208  of  280  ( 600  calculations / loop)
# Executing ext. loop: 209  of  280  ( 600  calculations / loop)
# Executing ext. loop: 210  of  280  ( 600  calculations / loop)
# Executing ext. loop: 211  of  280  ( 600  calculations / loop)
# Executing ext. loop: 212  of  280  ( 600  calculations / loop)
# Executing ext. loop: 213  of  280  ( 600  calculations / loop)
# Executing ext. loop: 214  of  280  ( 600  calculations / loop)
# Executing ext. loop: 215  of  280  ( 600  calculations / loop)
# Executing ext. loop: 216  of  280  ( 600  calculations / loop)
# Executing ext. loop: 217  of  280  ( 600  calculations / loop)
# Executing ext. loop: 218  of  280  ( 600  calculations / loop)
# Executing ext. loop: 219  of  280  ( 600  calculations / loop)
# Executing ext. loop: 220  of  280  ( 600  calculations / loop)
# Executing ext. loop: 221  of  280  ( 600  calculations / loop)
# Executing ext. loop: 222  of  280  ( 600  calculations / loop)
# Executing ext. loop: 223  of  280  ( 600  calculations / loop)
# Executing ext. loop: 224  of  280  ( 600  calculations / loop)
# Executing ext. loop: 225  of  280  ( 600  calculations / loop)
# Executing ext. loop: 226  of  280  ( 600  calculations / loop)
# Executing ext. loop: 227  of  280  ( 600  calculations / loop)
# Executing ext. loop: 228  of  280  ( 600  calculations / loop)
# Executing ext. loop: 229  of  280  ( 600  calculations / loop)
# Executing ext. loop: 230  of  280  ( 600  calculations / loop)
# Executing ext. loop: 231  of  280  ( 600  calculations / loop)
# Executing ext. loop: 232  of  280  ( 600  calculations / loop)
# Executing ext. loop: 233  of  280  ( 600  calculations / loop)
# Executing ext. loop: 234  of  280  ( 600  calculations / loop)
# Executing ext. loop: 235  of  280  ( 600  calculations / loop)
# Executing ext. loop: 236  of  280  ( 600  calculations / loop)
# Executing ext. loop: 237  of  280  ( 600  calculations / loop)
# Executing ext. loop: 238  of  280  ( 600  calculations / loop)
# Executing ext. loop: 239  of  280  ( 600  calculations / loop)
# Executing ext. loop: 240  of  280  ( 600  calculations / loop)
# Executing ext. loop: 241  of  280  ( 600  calculations / loop)
# Executing ext. loop: 242  of  280  ( 600  calculations / loop)
# Executing ext. loop: 243  of  280  ( 600  calculations / loop)
# Executing ext. loop: 244  of  280  ( 600  calculations / loop)
# Executing ext. loop: 245  of  280  ( 600  calculations / loop)
# Executing ext. loop: 246  of  280  ( 600  calculations / loop)
# Executing ext. loop: 247  of  280  ( 600  calculations / loop)
# Executing ext. loop: 248  of  280  ( 600  calculations / loop)
# Executing ext. loop: 249  of  280  ( 600  calculations / loop)
# Executing ext. loop: 250  of  280  ( 600  calculations / loop)
# Executing ext. loop: 251  of  280  ( 600  calculations / loop)
# Executing ext. loop: 252  of  280  ( 600  calculations / loop)
# Executing ext. loop: 253  of  280  ( 600  calculations / loop)
# Executing ext. loop: 254  of  280  ( 600  calculations / loop)
# Executing ext. loop: 255  of  280  ( 600  calculations / loop)
# Executing ext. loop: 256  of  280  ( 600  calculations / loop)
# Executing ext. loop: 257  of  280  ( 600  calculations / loop)
# Executing ext. loop: 258  of  280  ( 600  calculations / loop)
# Executing ext. loop: 259  of  280  ( 600  calculations / loop)
# Executing ext. loop: 260  of  280  ( 600  calculations / loop)
# Executing ext. loop: 261  of  280  ( 600  calculations / loop)
# Executing ext. loop: 262  of  280  ( 600  calculations / loop)
# Executing ext. loop: 263  of  280  ( 600  calculations / loop)
# Executing ext. loop: 264  of  280  ( 600  calculations / loop)
# Executing ext. loop: 265  of  280  ( 600  calculations / loop)
# Executing ext. loop: 266  of  280  ( 600  calculations / loop)
# Executing ext. loop: 267  of  280  ( 600  calculations / loop)
# Executing ext. loop: 268  of  280  ( 600  calculations / loop)
# Executing ext. loop: 269  of  280  ( 600  calculations / loop)
# Executing ext. loop: 270  of  280  ( 600  calculations / loop)
# Executing ext. loop: 271  of  280  ( 600  calculations / loop)
# Executing ext. loop: 272  of  280  ( 600  calculations / loop)
# Executing ext. loop: 273  of  280  ( 600  calculations / loop)
# Executing ext. loop: 274  of  280  ( 600  calculations / loop)
# Executing ext. loop: 275  of  280  ( 600  calculations / loop)
# Executing ext. loop: 276  of  280  ( 600  calculations / loop)
# Executing ext. loop: 277  of  280  ( 600  calculations / loop)
# Executing ext. loop: 278  of  280  ( 600  calculations / loop)
# Executing ext. loop: 279  of  280  ( 600  calculations / loop)
# ####################################
# ##########DBINVERT FINALIZED##########
# ####################################
# 4918.350928  TOTAL SECONDS FOR DBINVERT

# %%
from matplotlib import pyplot as plt
# %matplotlib widget
plt.figure(figsize=(11, 6))
plt.imshow(out[:,:,5,2].T)#,vmin=6,vmax=9.5) ##alog of density!
#plt.imshow(fenc.T)
#plt.imshow(yobs_a[:,:].T)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.set_printoptions(linewidth=180,precision=2,suppress=True)    
out1=np.copy(out)
for i in range(12):
    out1[:,:,i,1]=out1[:,:,i,1]*1e7
    out1[:,:,i,6]=out1[:,:,i,6]*180/np.pi
    out1[:,:,i,7]=out1[:,:,i,7]*180/np.pi
print("    index", "       chi^2","        ne" , "     Y height", "    X los", "     B" ,"          Phi", "      Theta", "      Bx", "        By", "         Bz" )
print(out1[130,270,:,:])

# np.set_printoptions(suppress=False)
# print(out[130,270,:,1])
# Out:
#     index        chi^2         ne      Y height     X los      B           Phi       Theta       Bx         By          Bz
# [[4374669.         2.43       8.29       1.13       0.03      18.17      14.08      78.88      17.29       4.34       3.5 ]
#  [4381509.         2.43       8.29       1.13       0.03     -18.16     166.93      78.88      17.36      -4.03      -3.5 ]
#  [4382781.         2.43       8.29       1.13       0.03     -18.16     195.08     103.15      17.08       4.6        4.13]
#  [4389621.         2.43       8.29       1.13       0.03      18.17     347.93     103.15      17.3       -3.7       -4.13]
#  [4374759.         3.5        8.29       1.13       0.03      18.34      16.09      78.88      17.29       4.99       3.54]
#  [4381419.         3.5        8.29       1.13       0.03     -18.34     164.92      78.88      17.37      -4.68      -3.54]
#  [4382871.         3.5        8.29       1.13       0.03     -18.34     197.09     103.15      17.07       5.25       4.17]
#  [4389531.         3.5        8.29       1.13       0.03      18.34     345.92     103.15      17.32      -4.34      -4.17]
#  [4374758.         4.33       8.29       1.13       0.03      18.49      16.09      76.85      17.3        4.99       4.21]
#  [4381418.         4.33       8.29       1.13       0.03     -18.49     164.92      76.85      17.39      -4.69      -4.21]
#  [4382872.         4.33       8.29       1.13       0.03     -18.49     197.09     105.17      17.06       5.25       4.84]
#  [4389532.         4.33       8.29       1.13       0.03      18.49     345.92     105.17      17.31      -4.34      -4.84]]

# %%
print(len(db1[3]),db1[3].shape)
print(db1[3][5,55,43,21,:])
# Out:
# 10 (10, 60, 180, 90, 8)
# [ 1.00000000e+00 -4.70111299e-03  4.37379255e-02 -4.39165539e-06
#   3.88484285e-01 -4.69583030e-05  4.36427498e-04 -3.49742398e-06]

# %%
print(len(db2[0]),db2[0].shape)
print(db2[2][5,55,43,21,:])
print(db2[1][5,55,43,21,:])
# Out:
# 10 (10, 60, 180, 90, 8)
# [ 1.00000000e+00 -4.19970207e-03  3.90317654e-02 -4.32276463e-06
#   3.43410422e-01 -4.66130961e-05  4.33219167e-04 -1.53864879e-06]
# [ 1.00000000e+00 -3.34808356e-03  3.11496936e-02 -4.35477813e-06
#   2.80491796e-01 -2.76344127e-05  2.56832484e-04 -1.25806758e-06]

# %%
gg=cle202_utils.sdbread_par('/home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0001.DAT',hdrparams,verbose)
# Out:
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1074/DB0001.DAT
# 77  MB in DB file

# %%
print(gg.shape)

print(gg[5,55,43,21,:]/gg[5,55,43,21,0])
for i in range(3,-1,-1):
    gg[:,:,:,:,i]=gg[:,:,:,:,i]/gg[:,:,:,:,0]
print(gg[5,55,43,21,:])
# Out:
# (10, 60, 180, 90, 4)
# [ 1.00000000e+00 -4.19970207e-03  3.90317654e-02 -4.32276463e-06]
# [ 1.00000000e+00 -4.19970207e-03  3.90317654e-02 -4.32276463e-06]

# %%
gg1=cle202_utils.sdbread_par('/home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0001.DAT',hdrparams,verbose)
# Out:
# READING INDIVIDUAL DATA...
# DB file location: /home/alin/Documents/physics_prog/cle/test_cle_degeneracy/db202_R0500/fe-xiii_1079/DB0001.DAT
# 77  MB in DB file
# 13.771253  SECONDS FOR INDIVIDUAL DB READ
# ----------

# %%
print(gg1[5,55,43,21,:])
# Out:
# [ 2.23802118e-07 -3.03779646e-11  2.82330882e-10 -1.00274435e-12]

# %%
print(db[2][5,55,43,21,:])
# Out:
# [ 1.00000000e+00 -4.19970207e-03  3.90317654e-02 -4.32276463e-06
#   3.43410422e-01 -4.66130961e-05  4.33219167e-04 -1.53864879e-06]
